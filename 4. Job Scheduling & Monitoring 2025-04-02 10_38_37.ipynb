# %%
# Import necessary libraries
from pyspark.sql.functions import current_timestamp
from pyspark.sql import SparkSession
import logging

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def monitor_table():
    spark = SparkSession.builder.appName("NewsMonitoring").getOrCreate()
    df = spark.read.table("the_news.news_table")
    df = df.withColumn("processed_time", current_timestamp())
    df.show(5)
    return df.count()

logger.info(f"Total records in table: {monitor_table()}")
# Out:
# INFO:py4j.clientserver:Python Server ready to receive messages
# INFO:py4j.clientserver:Received command c on object id p0
# INFO:py4j.clientserver:Python Server ready to receive messages
# INFO:py4j.clientserver:Received command c on object id p0
# +------------------+--------------------+-----------+-----------------+--------------------+--------------------+----------+---------+--------------+--------------------+
# |            source|               title|date_posted|           author|                 url|             content|word_count|sentiment|compound_score|      processed_time|
# +------------------+--------------------+-----------+-----------------+--------------------+--------------------+----------+---------+--------------+--------------------+
# |Hollywood Reporter|Sydney Sweeney, A...| 2025-04-01|    Ryan Gajewski|http://www.hollyw...|Sydney Sweeney jo...|       295| Positive|        0.9959|2025-04-02 21:43:...|
# |          Deadline|CinemaCon 2025: F...| 2025-04-01|      Robert Lang|https://deadline....|Billboard Women i...|       265| Negative|       -0.7579|2025-04-02 21:43:...|
# |          Deadline|Donnie Yen To Dir...| 2025-04-01|Nancy Tartaglione|http://deadline.c...|Billboard Women i...|       449| Positive|        0.9975|2025-04-02 21:43:...|
# |           Variety|Morgan Wallen Tur...| 2025-04-01|   Ethan Shanfeld|https://variety.c...|Billboard Women i...|       267| Positive|         0.991|2025-04-02 21:43:...|
# |               NPR|New Wet Leg, Sufj...| 2025-04-01|                 |https://www.npr.o...|New Wet Leg, Sufj...|       251| Positive|        0.9941|2025-04-02 21:43:...|
# +------------------+--------------------+-----------+-----------------+--------------------+--------------------+----------+---------+--------------+--------------------+
# only showing top 5 rows
# INFO:py4j.clientserver:Received command c on object id p0
# INFO:py4j.clientserver:Received command c on object id p0
# INFO:__main__:Total records in table: 29
